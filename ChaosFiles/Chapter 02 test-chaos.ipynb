# %%
# %load_ext autoreload
# %autoreload 2
from vector_drawing import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
draw_points = [(2,-2)]

# %%
dino_vectors = [(6,4), (3,1), (1,2), (-1,5), (-2,5), (-3,4), (-4,4),
    (-5,3), (-5,2), (-2,2), (-5,1), (-4,0), (-2,1), (-1,0), (0,-3),
    (-1,-4), (1,-4), (2,-3), (1,-2), (3,-1), (5,1)
]

# %%
draw(
    Points(*dino_vectors),
    Polygon(*dino_vectors)
     )

# %%
def add(v1, v2):
    return (v1[0] + v2[0], v1[1] + v2[1])

# %%
dino_vectors2 =  [add((1,-3.5), v) for v in dino_vectors]

# %%
draw(
    Points(*dino_vectors,color= blue),
    Polygon(*dino_vectors,color= blue),
    Points(*dino_vectors2,color= red),
    Polygon(*dino_vectors2,color= red),
)

# %%
from math import sqrt, atan


def length(v):
    return sqrt(v[0]**2 + v[1]**2)

# %%
def translate(translation, vectors):
    return [add(translation, v) for v in vectors]

translate((1,1), [(0,0), (0,1,), (-3,-3)])
# Out:
# [(1, 1), (1, 2), (-2, -2)]

# %%
def hundred_dinos():
    translations = [(20*x,10*y) 
                    for x in range(-10,5) 
                    for y in range(-5,5)]
    dinos = [Polygon(*translate(t, dino_vectors),color=blue)
                for t in translations]
    draw(*dinos, grid=None, axes=None, origin=None)

# %%
hundred_dinos()

# %%
from math import tan,pi,sin,cos

# %%
tan(45)
# Out:
# 1.6197751905438615

# %%
tan(pi/4)
# Out:
# 0.9999999999999999

# %%
def to_cartesian(polar_vector):
    length, angle = polar_vector[0], polar_vector[1]
    return length * cos(angle), length * sin(angle)

# %%
angle = 37*pi/180
to_cartesian((5,angle))
# Out:
# (3.993177550236464, 3.0090751157602416)

# %% [markdown]
# 反正弦

# %%
from math import asin
asin(1)
# Out:
# 1.5707963267948966

# %%
#下面之所以不出输出1，是因为python的三角函数默认接受的参数为弧度
sin(pi/4)
# tan(45)
# Out:
# 0.7071067811865476

# %%
asin(0.7071067811865476)
# Out:
# 0.7853981633974484

# %%
0.7853981633974484*180/pi
# Out:
# 45.00000000000001

# %%
from math import atan2,sqrt
def length(vector):
    return sqrt(vector[0]**2 + vector[1]**2)

#这里返回的第一个值为长度，第二个值为弧度
def to_polar(vector):
    x, y = vector[0], vector[1]
    angle = atan2(y,x)
    return length(vector), angle

# %%
to_polar((0,1))
# Out:
# (1.0, 1.5707963267948966)

# %%
to_polar((-1.34,2.68))
# Out:
# (2.9963310898497184, 2.0344439357957027)

# %%
to_cartesian((15,37*pi/180))
# Out:
# (11.979532650709393, 9.027225347280725)

# %%
rotation_angle = pi/2
dino_poloar = [to_polar(v) for v in dino_vectors]
dino_rotated_polar = [(l, angle + rotation_angle) for l, angle in dino_poloar]
dino_rotated = [to_cartesian(p) for p in dino_rotated_polar]


draw(
    Polygon(*dino_vectors, color=gray),
    Polygon(*dino_rotated,color= red)
)

# %%
def rotated_vector_list(rotation_angle,vectorlist):
    def to_polar(vector):
        x, y = vector[0], vector[1]
        angle = atan2(y,x)
        return length(vector), angle
    def to_cartesian(polar_vector):
        length, angle = polar_vector[0], polar_vector[1]
        return length * cos(angle), length * sin(angle)
    vector_list_polar = [to_polar(v) for v in vectorlist]
    rotated_polar = [(l, angle + rotation_angle) for l, angle in vector_list_polar]
    print(rotated_polar)
    rotated_vector_list = [ to_cartesian(p) for p in rotated_polar]
    print(rotated_vector_list)
    return rotated_vector_list

# %%
vector_list = [(9,17),(22,10)]
rotation_angle = pi/3
rotated_vector_list = rotated_vector_list(rotation_angle,vector_list)
for item in rotated_vector_list:
    print(item)
# Out:
# [(19.235384061671343, 2.131094646180225), (24.166091947189145, 1.4738250443234737)]
# [(-10.22243186433545, 16.29422863405995), (2.3397459621556163, 24.05255888325765)]
# (-10.22243186433545, 16.29422863405995)
# (2.3397459621556163, 24.05255888325765)
